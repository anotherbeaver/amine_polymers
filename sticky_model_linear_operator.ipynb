# %% [markdown]
# # Multiple Sticker Model
# Based off Indei & Takimoto (2010), we're gonna implement what they did and compare it to our model. The association and dissociation rates we will have to calculate ourselves from the simulations, so we can start with getting the same plots as they generate.
#
# We make the same assumption that the association and dissociation rates of all the stickers is the same, $\alpha, \beta$.
#
# Check out sticky_model.ipynb for the process of constructing this model. This notebook is just for matching it to our experimental data.

# %% [markdown]
# ## Generating $\mathbf{K}(l)$

# %%
import numpy as np

def recursive_K(l, alpha, beta):
    if l == 1:
        return np.array([[1, beta],[alpha, 1]])
    else:
        tl = recursive_K(l-1, alpha, beta)
        tr = beta * np.identity(2 ** (l-1))
        bl = alpha * np.identity(2 ** (l-1))
        br = recursive_K(l-1, alpha, beta)
        return np.block([[tl, tr],
                          [bl, br]])

def recursive_K_list(l, alpha_list, beta_list):
    if l == 1:
        return np.array([[1, beta_list[0]],[alpha_list[0], 1]])
    else:
        tl = recursive_K_list(l-1, alpha_list[:-1], beta_list[:-1])
        tr = beta_list[l-1] * np.identity(2 ** (l-1))
        bl = alpha_list[l-1] * np.identity(2 ** (l-1))
        br = recursive_K_list(l-1, alpha_list[:-1], beta_list[:-1])
        return np.block([[tl, tr],
                          [bl, br]])

# %% [markdown]
# ## Generating $\mathbf W(N_a)$

# %%
# N_a is the total number of stickers on a chain
def generate_W(N_a, alpha, beta):
    K_N_a = recursive_K(N_a, alpha, beta)
    K_upper = np.triu(K_N_a, 1)
    K_lower = np.tril(K_N_a, -1)
    
    W_diagonal = np.diagflat(-np.sum(K_N_a, axis=0)+1)

    return K_upper + K_lower + W_diagonal

def generate_W_lists(N_a, alpha_lit, beta_list):
    if len(alpha_lit) != len(beta_list) or len(alpha_lit) != N_a:
        raise ValueError("Incorrect number of association/dissociation parameters.")
    K_N_a = recursive_K_list(N_a, alpha_lit, beta_list)
    K_upper = np.triu(K_N_a, 1)
    K_lower = np.tril(K_N_a, -1)
    
    W_diagonal = np.diagflat(-np.sum(K_N_a, axis=0)+1)

    return K_upper + K_lower + W_diagonal

# %%
def extract_n_s(s, M, N_b):
    N_a = (N_b - 1) // M + 1
    if N_a < M:
        raise ValueError("N_a must be greater than or equal to M.")
    
    n_s = np.zeros(M * (N_a-1) + 1, dtype=int)

    index = 0
    while True:
        n_s[index] = s & 1
        s = s >> 1
        if s == 0:
            break
        if index >= M * (N_a-1):
            raise ValueError(f"s is too large to fit in the specified number of stickers and spacing, s^max = {2 ** N_a - 1}.")
        index += M
    return n_s

# %%
# Note: negating 0 gives -1, we have to add some int() typecasts
def generate_B(s, M, N_b):
    if (N_b-1) % M != 0:
        raise ValueError("N_b-1 must be divisible by M.")
    n_s = extract_n_s(s, M, N_b)
    B = np.zeros((N_b-1, N_b-1))

    for i, pair in enumerate(zip(n_s[:-1], n_s[1:])):
        if i != 0: # a_i
            B[i, i-1] = -1 * int(pair[0]==0)
        if i != N_b - 2: # c_i
            B[i, i+1] = -1 * int(pair[1]==0)
        # b_i
        B[i, i] = (int(pair[0]==0) or int(pair[1]==0)) + (int(pair[0]==0) and int(pair[1]==0))

    return B

# %% [markdown]
# # Solving equations for $h_{k,l}^s, g_{k,l}^s$
# We need to solve for coefficients $h_{k,l}^s, g_{k,l}^s$ governed by equation 25a
# $$
# - \omega h_{k,l}^s + \frac{k_b}{\zeta} \sum_{j=1}^{N_b-1}(B_{k,j}^sg_{j,l}^s + B_{l,j}^sg_{k,j}^s) = \sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime, s} g_{k,l}^{s^\prime}
# $$
# and 25b
# $$
# \omega g_{k,l}^s-\omega \delta_{k,l} + \frac{k_b}{\zeta}\sum_{j=1}^{N_b-1}(B_{k,j}^sh_{j,l}^s+B_{l,j}^sh_{k,j}^s)=\sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime,s}h_{k,l}^{s^\prime}
# $$

# %%
import numpy as np

# physical chain parameters
N_b = 31
N_a = 7
M = 5
s_max = 2**N_a - 1

# calculation parameters
omega = 1
k_b = 1
zeta = 1

vectorize_length = (N_b - 1) * (N_b - 1) * (s_max + 1)

# vectorize h, k --> goes from (N_b - 1) x (N_b - 1) x (s_max + 1) to (N_b - 1) * (N_b - 1) * (s_max + 1) x 1
g = np.zeros(vectorize_length)
h = np.zeros(vectorize_length)

x = np.concatenate((g,h))
# grouped like l, then k, then s -> N_b - 1 elements along axis l, then N_b - 1 of those for axis k, then s_max + 1 of those for axis s. 

"""
Convert indices s, k, l to index of vectorized g. 
note that k,l indices are 1-based, hence (index-1), but s is 0-based

In the vector x (concatenate g and h) g comes first.

Args:
    - s: s index, in [1, s_{max} + 1]
    - k: k index, in [1, N_b - 1]
    - l: l index, in [1, N_b - 1]
    - s_max: maximum association state
    - N_b: number of beads

Returns: 
    - index along vectorized g vector
"""
def g_index(s, k, l, s_max, N_b):
    return s*(N_b-1)**2 + (k-1)*(N_b-1) + (l-1)

"""
Convert indices s, k, l to index of vectorized h. 
note that k,l indices are 1-based, hence (index-1), but s is 0-based

In the vector x (concatenate g and h) h comes second, offset by (N_b-1) * (N_b-1) * (s_max+1)

Args:
    - s: s index, in [1, s_{max} + 1]
    - k: k index, in [1, N_b - 1]
    - l: l index, in [1, N_b - 1]
    - s_max: maximum association state
    - N_b: number of beads

Returns: 
    - index along vectorized g vector
"""
def h_index(s, k, l, s_max, N_b):
    # print((s_max+1))
    # print((N_b-1))
    # print((s_max+1)*(N_b-1)**2 + s*(N_b-1)**2 + (k-1)*(N_b-1) + (l-1))
    return (s_max+1)*(N_b-1)**2 + s*(N_b-1)**2 + (k-1)*(N_b-1) + (l-1)

# %%
    from scipy.sparse import lil_matrix, csr_matrix, csc_matrix, coo_matrix
    from scipy.sparse.linalg import LinearOperator
    from time import time


    """
    Hacky way to get Ax to accept only one input vector x, but still have access to all the other parameters.


    """


    """
    Linear operator form of A, does not need to store/manipulate the full matrix. Intended for use with iterative solvers like GMRES.

    Uses the same indexing scheme as the full matrix, check out construct_Ab for more details.

    Args:
        - x: vectorized g and h, stacked
        - omega: omega value to calculate shear dynamic moduli -- each omega value gives us one value of G' and G'' each
        - B: (s_max + 1) x (N_b - 1) x (N_b - 1) bead connectivity matrix
        - W: (s_max + 1) x (s_max + 1) association state transition matrix
        - k_b: spring constant along backbone beads
        - zeta: friction constant from Langevin equation (also dimensionless friction constant, they are interchangeable)
        - N_k: number of Kuhn steps in one chain, used if dimensionless (i.e. if k_b is none, replaces k_b)
        - N_b: number of beads in one chain
        - M: spacing of stickers
        - N_a: number of stickers in one chain (if None, is calculated)
        - s_max: maximum association state (if None, is calculated)

    Returns:
        - Ax: result of applying linear operator A to vector x

    """
    def A_operator(x, omega, B, W, k_b=None, zeta=1e-5, N_k=128, N_b=31, M=5, N_a=7, s_max=None):
        if N_a == None:
            N_a = (N_b - 1) // M + 1
        
        if s_max == None:
            s_max = 2**N_a - 1
        
        vectorize_length = (s_max + 1) * (N_b - 1) * (N_b - 1)

        if k_b == None:
            k_b_zeta = 3/(zeta * N_k)
        else:
            k_b_zeta = k_b/zeta


        Ax = np.zeros_like(x)

        # print("B:", B.shape)
        # print("x:", x.shape)
        # print("vectorize_length:", vectorize_length)
        # print("N_b:", N_b)
        # print("N_k:", N_k)


        # this is pass by reference btw
        g = x[:vectorize_length].reshape(s_max+1, N_b-1, N_b-1)
        h = x[vectorize_length:].reshape(s_max+1, N_b-1, N_b-1)

        Ax_g = Ax[:vectorize_length].reshape(s_max+1, N_b-1, N_b-1)
        Ax_h = Ax[vectorize_length:].reshape(s_max+1, N_b-1, N_b-1)

        Wg = np.tensordot(W.T, g, axes=(1,0))
        Wh = np.tensordot(W.T, h, axes=(1,0))
        
        for s in range(s_max+1):
            Bs = B[s]
            # Ws = W[:, s]
            gs = g[s]
            hs = h[s]
            # Ax_gs = Ax_g[s]
            # Ax_hs = Ax_h[s]

            Bg_left = Bs @ gs
            Bg_right = gs @ Bs.T

            Bh_left = Bs @ hs
            Bh_right = hs @ Bs.T

            # Ax_gs = -omega * hs + k_b_zeta * Bg_left + k_b_zeta * Bg_right - Wg[s]
            # Ax_hs = omega * gs + k_b_zeta * Bh_left + k_b_zeta * Bh_right - Wh[s]

            # for k in range(0, N_b-1):
            #     for l in range(0, N_b-1):
            #         # row_g = g_index(s, k, l, s_max, N_b)
            #         # row_h = h_index(s, k, l, s_max, N_b)

            #         # Equation 25a
            #         Ax_gs[k, l] += -omega * hs[k, l]
            #         Ax_gs[k, l] += k_b_zeta * Bg_left[k, l]
            #         Ax_gs[k, l] += k_b_zeta * Bg_right[k, l]
            #         Ax_gs[k, l] += -Wg[s, k, l]

            #         # Equation 25b
            #         Ax_hs[k, l] += omega * gs[k, l]
            #         Ax_hs[k, l] += k_b_zeta * Bh_left[k, l]
            #         Ax_hs[k, l] += k_b_zeta * Bh_right[k, l]
            #         Ax_hs[k, l] += -Wh[s, k, l]
            Ax_g[s] = -omega * hs + k_b_zeta * Bg_left + k_b_zeta * Bg_right - Wg[s]
            Ax_h[s] = omega * gs + k_b_zeta * Bh_left + k_b_zeta * Bh_right - Wh[s]

            Ax[:vectorize_length] = Ax_g.reshape(vectorize_length)
            Ax[vectorize_length:] = Ax_h.reshape(vectorize_length)

        return Ax


    """
    Construct coupling matrix A and constant RHS b such that we can solve an equation Ax = b to get values of g, h
    In this form, x is stacked vectorized g and h. Each row of A encodes an equation.
    A encodes equation 25a in the first vectorize_length rows, and 25b in the second vectorize_length rows.

    We additionally need B^s_{k,l} and W_{s', s} matrices. W isn't a problem, but B needs to be composed into a 
    tensor for each valid value of s.

    Generating with COO sparse matrix is the fastest out of what I tested.

    Args:
        - omega: omega value to calculate shear dynamic moduli -- each omega value gives us one value of G' and G'' each
        - B: (s_max + 1) x (N_b - 1) x (N_b - 1) bead connectivity matrix
        - W: (s_max + 1) x (s_max + 1) association state transition matrix
        - k_b: spring constant along backbone beads
        - zeta: friction constant from Langevin equation (also dimensionless friction constant, they are interchangeable)
        - N_k: number of Kuhn steps in one chain, used if dimensionless (i.e. if k_b is none, replaces k_b)
        - N_b: number of beads in one chain
        - M: spacing of stickers
        - N_a: number of stickers in one chain (if None, is calculated)
        - s_max: maximum association state (if None, is calculated)
        - pbar: optional tqdm progress bar to update during construction (single global bar)
    Returns:
        - A: matrix A encoding equations 25a and 25b to be applied to vectorized g and h.
        - b: RHS constants from equations 25a and 25b
    """
    def construct_Ab(omega, B, W, k_b=None, zeta=1e-5, N_k=128, N_b=15, M=2, N_a=8, s_max=None, pbar=None, operator=False):
        start = time()

        if N_a == None:
            N_a = (N_b - 1) // M + 1
        
        if s_max == None:
            s_max = 2**N_a - 1
        
        vectorize_length = (s_max + 1) * (N_b - 1) * (N_b - 1)

        if k_b == None:
            k_b_zeta = 3/(zeta * N_k)
            print(f"Using dimensionless k_b = 1/N_k = {1/N_k}, zeta = {zeta}, so k_b/zeta = {k_b_zeta}")
        else:
            k_b_zeta = k_b/zeta
            print(f"Using k_b = {k_b}, zeta = {zeta}, so k_b/zeta = {k_b_zeta}")

        rows = []
        cols = []
        data = []

        b_rows = []
        b_cols = []
        b_data = []
        
        if operator:
            b = np.zeros((2 * vectorize_length, 1))

            for s in range(s_max + 1):
                for k in range (1, N_b):
                    for l in range (1, N_b):
                        # for 25b, b = \omega \delta_{k,l}
                        if k == l:
                            b[h_index(s, k, l, s_max, N_b), 0] += omega
            A = LinearOperator((2 * vectorize_length, 2 * vectorize_length), matvec=lambda x: A_operator(x, omega, B, W, k_b=k_b, zeta=zeta, N_k=N_k, N_b=N_b, M=M, N_a=N_a, s_max=s_max))
            return A, b

        else:
            for s in range(s_max+1):
                for k in range (1, N_b):
                    for l in range (1, N_b):
                        # print(f"{s} {k} {l}")
                        # ---------------------------------------------
                        # eqn. 25a
                        # ---------------------------------------------
                        row = g_index(s, k, l, s_max, N_b)

                        rows.append(row)
                        cols.append(h_index(s, k, l, s_max, N_b))
                        data.append(-omega) # -\omega h_{k,l}^s
                        # A[row, h_index(s, k, l, s_max, N_b)] += -omega # -\omega h_{k,l}^s
                        
                        # + \frac{k_b}{\zeta} \sum_{j=1}^{N_b-1}(B_{k,j}^sg_{j,l}^s + B_{l,j}^sg_{k,j}^s)
                        for j in range(1, N_b): # j from 1 to N_b - 1
                            rows.append(row)
                            cols.append(g_index(s, j, l, s_max, N_b))
                            data.append(k_b_zeta * B[s, k-1, j-1])
                            rows.append(row)
                            cols.append(g_index(s, k, j, s_max, N_b))
                            data.append(k_b_zeta * B[s, l-1, j-1])
                            # A[row, g_index(s, j, l, s_max, N_b)] += k_b_zeta * B[s, k-1, j-1] # again, k and l are 1-based indices
                            # A[row, g_index(s, k, j, s_max, N_b)] += k_b_zeta * B[s, l-1, j-1]

                        # - \sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime, s} g_{k,l}^{s^\prime}
                        for s_i in range(s_max + 1): # s_i from 0 to s_max
                            rows.append(row)
                            cols.append(g_index(s_i, k, l, s_max, N_b))
                            data.append(-W[s_i, s])
                            # A[row, g_index(s_i, k, l, s_max, N_b)] += -W[s_i, s] # but s is 0-based index

                        # for 25a, b = 0
                        # update global progress bar (one unit per (s,k,l) processed for eqn 25a)
                        if pbar is not None:
                            pbar.update(1)
            
            # restart loop -- we want to be writing second half of A AFTER first half to take advantage of lil_matrix
            for s in range(s_max + 1):
                for k in range (1, N_b):
                    for l in range (1, N_b):
                        # ---------------------------------------------
                        # eqn. 25b
                        # ---------------------------------------------
                        row = h_index(s, k, l, s_max, N_b)

                        rows.append(row)
                        cols.append(g_index(s, k, l, s_max, N_b))
                        data.append(omega) # \omega g_{k,l}^s
                        # A[row, g_index(s, k, l, s_max, N_b)] += omega # \omega g_{k,l}^s
                        
                        # + \frac{k_b}{\zeta}\sum_{j=1}^{N_b-1}(B_{k,j}^sh_{j,l}^s+B_{l,j}^sh_{k,j}^s)
                        for j in range(1, N_b):
                            rows.append(row)
                            cols.append(h_index(s, j, l, s_max, N_b))
                            data.append(k_b_zeta * B[s, k-1, j-1])
                            rows.append(row)
                            cols.append(h_index(s, k, j, s_max, N_b))
                            data.append(k_b_zeta * B[s, l-1, j-1])
                            # A[row, h_index(s, j, l, s_max, N_b)] += k_b_zeta * B[s, k-1, j-1]
                            # A[row, h_index(s, k, j, s_max, N_b)] += k_b_zeta * B[s, l-1, j-1]

                        # - \sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime, s} h_{k,l}^{s^\prime}
                        for s_i in range(s_max + 1): # s_i from 0 to s_max
                            rows.append(row)
                            cols.append(h_index(s_i, k, l, s_max, N_b))
                            data.append(-W[s_i, s])
                            # A[row, h_index(s_i, k, l, s_max, N_b)] += -W[s_i, s]

                        # for 25b, b = \omega \delta_{k,l}
                        if k == l:
                            b_rows.append(h_index(s, k, l, s_max, N_b))
                            b_cols.append(0)
                            b_data.append(omega)
                            # b[h_index(s, k, l, s_max, N_b),0] += omega

                        # update global progress bar (one unit per (s,k,l) processed for eqn 25b)
                        if pbar is not None:
                            pbar.update(1)

            end = time()
            print(f"Finished constructing entries in {end - start:.2f} seconds")
            start = end

            A = coo_matrix((data, (rows, cols)), (2 * vectorize_length, 2 * vectorize_length)) # sized to be the same as x
            b = coo_matrix((b_data, (b_rows, b_cols)),(2 * vectorize_length, 1))

            A.eliminate_zeros()
            b.eliminate_zeros()

            A.sum_duplicates()
            b.sum_duplicates()

            end = time()
            print(f"Finished summing duplicates/eliminating zeros in {end - start:.2f} seconds")

            return A.tocsc(), b.tocsc()

# %%
def B_tensor(M=2, N_b=15):
    N_a = (N_b - 1) // M + 1
    s_max = 2**N_a - 1
    B = np.zeros((s_max + 1, N_b-1, N_b-1))
    for s in range(2**N_a):
        B_mat = generate_B(s=s, M=M, N_b=N_b)
        B[s] = B_mat
    return B
# B_tensor()

# %%
def count_associated(s, M=2, N_b=15):
    return np.sum(extract_n_s(s, M, N_b))

# n_c is density of chains
def nu_s(s, alpha, beta, M, N_b, n_c=1):
    N_a = (N_b - 1) // M + 1
    N_s = count_associated(s, M, N_b)
    return alpha**N_s * beta**(N_a - N_s) / (alpha + beta)**N_a * n_c
    

def dynamic_shear_moduli(x, alpha, beta, s_max, M, N_b, k_B=1, T=1, n_c=1):
    length = len(x)//2
    # print(length)
    g = np.reshape(x[:length], (s_max+1, N_b-1, N_b-1))
    h = np.reshape(x[length:], (s_max+1, N_b-1, N_b-1))

    G_p = 0
    G_pp = 0 
    for s in range(s_max+1):
        for k in range(N_b-1):
            G_p += k_B*T* nu_s(s, alpha, beta, M, N_b, n_c)*g[s, k, k]
            G_pp += k_B*T* nu_s(s, alpha, beta, M, N_b, n_c)*h[s, k, k]

    return G_p, G_pp

# %%
from tqdm.notebook import tqdm
from scipy.sparse.linalg import gmres
from joblib import Parallel, delayed
from time import time
from threadpoolctl import threadpool_limits

# Compute total work: each omega requires processing two blocks (25a and 25b) over (s,k,l)
# per_omega_updates = 2 * (s_max + 1) * (N_b - 1) * (N_b - 1)
# total_updates = len(new_omegas) * per_omega_updates
# omegas = omegas[-6:]
def solve_omega(omega, thread_limit=3, alpha=1, beta=1, N_b=15, N_a=8, M=2, n_c=1, operator=False):
    s_max = 2**N_a - 1

    # generating matrices
    B = B_tensor(M=M, N_b=N_b)
    W = generate_W(N_a=N_a, alpha=alpha, beta=beta)

    with threadpool_limits(limits=thread_limit):
        start = time()
        if operator:
            A, b = construct_Ab(omega, B, W, k_b=None, zeta=1e-5, N_b=N_b, M=M, N_a=N_a, s_max=s_max, operator=True)
            print("Matrix constructed.")

            # print("A.shape = ", A.shape)
            # print("b.shape = ", b.shape)
            # solving x
            x, info = gmres(A, b)
            print("Solved for x")
            assert info == 0, f"GMRES did not converge, info = {info}"
            G_p, G_pp = dynamic_shear_moduli(x, alpha=alpha, beta=beta, s_max=s_max, M=M, N_b=N_b, k_B=1, T=1, n_c=n_c)
            print(f"Omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}, time taken: {time() - start:.2f} seconds")
            del A, b, x
        else:
            A, b = construct_Ab(omega, B, W, k_b=None, zeta=1e-5, N_b=N_b, M=M, N_a=N_a, s_max=s_max)
            print("Matrix constructed.")

            # solving x
            x, info = gmres(A, b)
            print("Solved for x")
            assert info == 0, f"GMRES did not converge, info = {info}"
            G_p, G_pp = dynamic_shear_moduli(x, alpha=alpha, beta=beta, s_max=s_max, M=M, N_b=N_b, k_B=1, T=1, n_c=n_c  )
            print(f"Omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}, time taken: {time() - start:.2f} seconds")
            del A, b, x
        return omega, G_p, G_pp

# %%
omegas = np.logspace(-3, 3, 20)
G_p_list = []
G_pp_list = []

# for omega in tqdm(omegas):
#     # pbar = tqdm(total=per_omega_updates, desc='matrix construction progress')
#     A, b = construct_Ab(omega, B, W)
#     print("Matrix constructed.")

#     omega, G_p, G_pp = solve_omega(omega)

#     G_p_list.append(G_p)
#     G_pp_list.append(G_pp)

# %%
omegas = np.logspace(-3, 3, 20)[::-1]
G_p_list = []
G_pp_list = []

print("jobs for results_1 to do: ", len(omegas[omegas < 1e2]))

results_1 = Parallel(n_jobs=5)(
    delayed(solve_omega)(thread_limit=6,omega=omega, operator=True) for omega in omegas[omegas < 1e2]
)
# solve_omega(thread_limit=12,omega=1e-3, operator=True)
# Out:
# jobs for results_1 to do:  16
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Matrix constructed.
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Matrix constructed.
# Matrix constructed.
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Matrix constructed.
# Matrix constructed.
# Solved for x
# Omega: 54.5559, G_p: 3.0472, G_pp: 0.2845, time taken: 40.07 seconds
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Matrix constructed.
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Matrix constructed.
# Matrix constructed.
# Matrix constructed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 7
#       3 G_pp_list = []
#       4
#       5 print("jobs for results_1 to do: ", len(omegas[omegas < 1e2]))
#       6
# ----> 7 results_1 = Parallel(n_jobs=5)(
#       8     delayed(solve_omega)(thread_limit=6,omega=omega, operator=True) for omega in omegas[omegas < 1e2]
#       9 )
#      10 # solve_omega(thread_limit=12,omega=1e-3, operator=True)
#
# File ~/.venv/lib/python3.14/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/.venv/lib/python3.14/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/.venv/lib/python3.14/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
# testing if larger omegas take more memory, so we need fewer threads to avoid oom. 
# can use more threads, less jobs, more threads per job.
results_2 = Parallel(n_jobs=5)( 
    delayed(solve_omega)(omega, thread_limit=4, operator=True) for omega in omegas[omegas >= 1e2]
)
# Out:
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
#
# Matrix constructed.
# Matrix constructed.
# Matrix constructed.
# Matrix constructed.
# Solved for x
# 50176
# Omega: 1000.0000, G_p: 4.1245, G_pp: 1.8746, time taken: 37.53 seconds
# Solved for x
# 50176
# Omega: 483.2930, G_p: 3.5611, G_pp: 1.1927, time taken: 53.98 seconds
# Solved for x
# 50176
# Omega: 233.5721, G_p: 3.2612, G_pp: 0.7247, time taken: 78.87 seconds
# Solved for x
# 50176
# Omega: 112.8838, G_p: 3.1131, G_pp: 0.4344, time taken: 131.64 seconds

# %%
N_k = 128
zeta_tilde = 1e-5
N_b = 15

t_rouse = N_k * zeta_tilde * N_b**2 / np.pi**2
print("Rouse time:", t_rouse)
# Out:
# Rouse time: 0.029180500888993283

# %%
# omegas, G_p_list, G_pp_list = zip(*results_1, *results_2)

# Merge results from the two Parallel() calls, sort by omega, and unpack into arrays
results = []
results.extend(results_1)
results.extend(results_2)

# sort by omega to ensure smooth curves
results_sorted = sorted(results, key=lambda t: t[0])

# unpack
omegas, G_p_list, G_pp_list = zip(*results_sorted)

# convert to numpy arrays for plotting/processing
import numpy as np
omegas = np.array(omegas)
G_p_list = np.array(G_p_list)
G_pp_list = np.array(G_pp_list)

print(f"Collected {len(omegas)} omegas after merging. omegas min/max: {omegas.min():.3g}/{omegas.max():.3g}")
# Out:
# Collected 20 omegas after merging. omegas min/max: 0.001/1e+03

# %%
import pandas as pd
df = pd.DataFrame({
    'omega': omegas,
    'G_p': G_p_list,
    'G_pp': G_pp_list
})

# df.to_csv('data/comparison/Gp_Gpp_output_correct.csv', index=False)

# %%
# raise Exception("I am interrupting you.")

# %%
import pandas as pd

f = "data/comparison/Gp_Gpp_output_correct.csv"

# with open(f, "r") as file:
#     lines = file.readlines()
omegas = []
G_p_list = []
G_pp_list = []

# for line in lines:
#     if line.startswith("Omega"):
#         # print(line.split())
#         omegas.append(float(line.split()[1][:-1]))
#         G_p_list.append(float(line.split()[3][:-1]))
#         G_pp_list.append(float(line.split()[5][:-1]))

# print(omegas)
# print(G_p_list)
# print(G_pp_list)

my_data = pd.read_csv(f, skiprows=1, names=["omega", "G'", "G''"])
omegas = my_data["omega"].to_numpy()
G_p_list = my_data["G'"].to_numpy()
G_pp_list = my_data["G''"].to_numpy()

# %%
import pandas as pd

paper_sticky_model_G_p_alpha_1 = pd.read_csv("data/comparison/sticky_Gp_alpha_1.csv", names=["omega", "G'"])
paper_sticky_model_G_pp_alpha_1 = pd.read_csv("data/comparison/sticky_Gpp_alpha_1.csv", names=["omega", "G''"])
my_sticky_model_moduli_alpha_1 = pd.read_csv("data/comparison/my_sticky_model_alpha_1.csv")
print(paper_sticky_model_G_p_alpha_1.head())
# Out:
#       omega        G'
# 0  0.020515  0.001256
# 1  0.023709  0.001674
# 2  0.027042  0.002182
# 3  0.030844  0.002837
# 4  0.035180  0.003688

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(8,6))
plt.loglog(omegas, G_p_list, color='g', label=f"G' (my model, N_k=128)")
plt.loglog(omegas, G_pp_list, color='g', linestyle='--', label="G'' (my model, N_k=128)")
# plt.loglog(my_sticky_model_moduli_alpha_1["omega"], my_sticky_model_moduli_alpha_1["G'"], color='b', label=f"G' (my model, k_b=1)")
# plt.loglog(my_sticky_model_moduli_alpha_1["omega"], my_sticky_model_moduli_alpha_1["G''"], color='b', linestyle='--', label="G'' (my model, k_b=1)")
plt.loglog(paper_sticky_model_G_p_alpha_1["omega"], paper_sticky_model_G_p_alpha_1["G'"], color='r', label="G'' (paper data)")
plt.loglog(paper_sticky_model_G_pp_alpha_1["omega"], paper_sticky_model_G_pp_alpha_1["G''"], color='r', linestyle='--', label="G'' (paper data)")
plt.title(r"Dynamic shear moduli for sticky model with $\alpha/\beta=1, M=2, N_b=15$")
plt.xlabel(r"$\omega$")
plt.ylabel(r"$G', G''$")
plt.xlim(1e-3, 1e3)
plt.ylim(1e-3, 1e1)
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.legend()
plt.grid()  
plt.show()

# %%
# FIG. 4 top

alphas = [0.001, 1/3, 1, 10, 100]
omegas = np.logspace(-3, 3, 40)
omega_list_fig4_top = []
G_p_list_fig4_top = []
G_pp_list_fig4_top = []

for alpha in alphas:
    for omega in omegas:
        W = generate_W(8, alpha, 1) # beta is always 1 (in units of 1/beta)
        B = B_tensor()
        A, b = construct_Ab(omega, B, W, N_k=128)
        x = spsolve(A, b)
        G_p, G_pp = dynamic_shear_moduli(x, alpha, 1, 2**8-1, 2, 15)
        print(f"alpha: {alpha:.4f}, omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}")
        omega_list_fig4_top.append(omega)
        G_p_list_fig4_top.append(G_p)
        G_pp_list_fig4_top.append(G_pp)
        del A, b, x, G_p, G_pp, W, B

# FIG. 4 bottom

alphas = [1e3, 1e4, 1e5, 1e6]
omegas = np.logspace(-5, 1, 40)
omega_list_fig4_bottom = []
G_p_list_fig4_bottom = []
G_pp_list_fig4_bottom = []

for alpha in alphas:
    for omega in omegas:
        W = generate_W(8, alpha, 1) # beta is always 1 (in units of 1/beta)
        B = B_tensor()
        A, b = construct_Ab(omega, B, W, N_k=128)
        x = spsolve(A, b)
        G_p, G_pp = dynamic_shear_moduli(x, alpha, 1, 2**8-1, 2, 15)
        print(f"alpha: {alpha:.4f}, omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}")
        omega_list_fig4_bottom.append(omega)
        G_p_list_fig4_bottom.append(G_p)
        G_pp_list_fig4_bottom.append(G_pp)
        del A, b, x, G_p, G_pp, W, B
# Out:
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0010, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0014, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.03 seconds
# 50176
# alpha: 0.0010, omega: 0.0020, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0029, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0041, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.03 seconds
# 50176
# alpha: 0.0010, omega: 0.0059, G_p: 0.0000, G_pp: 0.0000
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.03 seconds
# 50176
# alpha: 0.0010, omega: 0.0084, G_p: 0.0000, G_pp: 0.0001
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0119, G_p: 0.0000, G_pp: 0.0001
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.03 seconds
# 50176
# alpha: 0.0010, omega: 0.0170, G_p: 0.0000, G_pp: 0.0001
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0242, G_p: 0.0000, G_pp: 0.0002
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.80 seconds
# Finished summing duplicates/eliminating zeros in 3.03 seconds
# 50176
# alpha: 0.0010, omega: 0.0346, G_p: 0.0000, G_pp: 0.0003
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0492, G_p: 0.0000, G_pp: 0.0004
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.0702, G_p: 0.0000, G_pp: 0.0006
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.1000, G_p: 0.0000, G_pp: 0.0008
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 0.0010, omega: 0.1425, G_p: 0.0000, G_pp: 0.0011
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.2031, G_p: 0.0000, G_pp: 0.0016
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.2894, G_p: 0.0000, G_pp: 0.0023
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.98 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.4125, G_p: 0.0000, G_pp: 0.0033
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.5878, G_p: 0.0000, G_pp: 0.0047
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 0.8377, G_p: 0.0000, G_pp: 0.0067
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.08 seconds
# 50176
# alpha: 0.0010, omega: 1.1938, G_p: 0.0000, G_pp: 0.0096
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 0.0010, omega: 1.7013, G_p: 0.0001, G_pp: 0.0137
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 0.0010, omega: 2.4245, G_p: 0.0002, G_pp: 0.0195
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 3.4551, G_p: 0.0003, G_pp: 0.0278
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 4.9239, G_p: 0.0007, G_pp: 0.0395
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 7.0170, G_p: 0.0014, G_pp: 0.0563
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 10.0000, G_p: 0.0027, G_pp: 0.0802
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 14.2510, G_p: 0.0055, G_pp: 0.1141
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 20.3092, G_p: 0.0110, G_pp: 0.1620
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 28.9427, G_p: 0.0221, G_pp: 0.2293
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 41.2463, G_p: 0.0438, G_pp: 0.3224
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 58.7802, G_p: 0.0852, G_pp: 0.4479
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 83.7678, G_p: 0.1604, G_pp: 0.6092
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 119.3777, G_p: 0.2857, G_pp: 0.8009
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 170.1254, G_p: 0.4693, G_pp: 1.0069
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 242.4462, G_p: 0.7001, G_pp: 1.2132
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 345.5107, G_p: 0.9593, G_pp: 1.4298
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 492.3883, G_p: 1.2489, G_pp: 1.6840
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.0010, omega: 701.7038, G_p: 1.5927, G_pp: 1.9926
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.0010, omega: 1000.0000, G_p: 2.0140, G_pp: 2.3550
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0010, G_p: 0.0000, G_pp: 0.0008
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0014, G_p: 0.0000, G_pp: 0.0011
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0020, G_p: 0.0000, G_pp: 0.0016
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0029, G_p: 0.0000, G_pp: 0.0023
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0041, G_p: 0.0000, G_pp: 0.0032
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0059, G_p: 0.0000, G_pp: 0.0046
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0084, G_p: 0.0000, G_pp: 0.0065
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0119, G_p: 0.0001, G_pp: 0.0093
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0170, G_p: 0.0002, G_pp: 0.0133
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 0.0242, G_p: 0.0003, G_pp: 0.0189
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.79 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0346, G_p: 0.0007, G_pp: 0.0270
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.79 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0492, G_p: 0.0014, G_pp: 0.0384
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.0702, G_p: 0.0028, G_pp: 0.0547
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.1000, G_p: 0.0056, G_pp: 0.0777
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 0.1425, G_p: 0.0113, G_pp: 0.1101
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.2031, G_p: 0.0227, G_pp: 0.1551
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.2894, G_p: 0.0451, G_pp: 0.2162
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.4125, G_p: 0.0873, G_pp: 0.2949
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.5878, G_p: 0.1624, G_pp: 0.3873
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 0.8377, G_p: 0.2823, G_pp: 0.4775
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 1.1938, G_p: 0.4455, G_pp: 0.5387
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 1.7013, G_p: 0.6284, G_pp: 0.5479
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 2.4245, G_p: 0.7958, G_pp: 0.5053
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 3.4551, G_p: 0.9239, G_pp: 0.4328
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 4.9239, G_p: 1.0092, G_pp: 0.3570
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 7.0170, G_p: 1.0611, G_pp: 0.2958
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 10.0000, G_p: 1.0918, G_pp: 0.2581
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 14.2510, G_p: 1.1122, G_pp: 0.2467
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 20.3092, G_p: 1.1308, G_pp: 0.2625
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 28.9427, G_p: 1.1553, G_pp: 0.3058
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.94 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 41.2463, G_p: 1.1935, G_pp: 0.3766
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 58.7802, G_p: 1.2525, G_pp: 0.4730
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 83.7678, G_p: 1.3377, G_pp: 0.5922
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 119.3777, G_p: 1.4516, G_pp: 0.7327
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 170.1254, G_p: 1.5962, G_pp: 0.8957
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 0.3333, omega: 242.4462, G_p: 1.7740, G_pp: 1.0852
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 345.5107, G_p: 1.9903, G_pp: 1.3081
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 492.3883, G_p: 2.2550, G_pp: 1.5714
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.80 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 701.7038, G_p: 2.5814, G_pp: 1.8798
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 0.3333, omega: 1000.0000, G_p: 2.9851, G_pp: 2.2359
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0010, G_p: 0.0000, G_pp: 0.0028
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0014, G_p: 0.0000, G_pp: 0.0040
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0020, G_p: 0.0000, G_pp: 0.0057
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0029, G_p: 0.0000, G_pp: 0.0081
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1.0000, omega: 0.0041, G_p: 0.0001, G_pp: 0.0115
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0059, G_p: 0.0001, G_pp: 0.0164
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.95 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0084, G_p: 0.0002, G_pp: 0.0234
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1.0000, omega: 0.0119, G_p: 0.0004, G_pp: 0.0333
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1.0000, omega: 0.0170, G_p: 0.0009, G_pp: 0.0474
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1.0000, omega: 0.0242, G_p: 0.0017, G_pp: 0.0675
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1.0000, omega: 0.0346, G_p: 0.0035, G_pp: 0.0962
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1.0000, omega: 0.0492, G_p: 0.0072, G_pp: 0.1369
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.0702, G_p: 0.0145, G_pp: 0.1944
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.1000, G_p: 0.0293, G_pp: 0.2753
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.1425, G_p: 0.0587, G_pp: 0.3875
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.2031, G_p: 0.1158, G_pp: 0.5387
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 0.2894, G_p: 0.2225, G_pp: 0.7319
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 1.0000, omega: 0.4125, G_p: 0.4080, G_pp: 0.9558
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 1.0000, omega: 0.5878, G_p: 0.6963, G_pp: 1.1745
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 1.0000, omega: 0.8377, G_p: 1.0831, G_pp: 1.3333
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1.0000, omega: 1.1938, G_p: 1.5260, G_pp: 1.3868
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 1.7013, G_p: 1.9633, G_pp: 1.3220
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 2.4245, G_p: 2.3369, G_pp: 1.1604
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 3.4551, G_p: 2.6132, G_pp: 0.9497
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 4.9239, G_p: 2.7931, G_pp: 0.7394
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 7.0170, G_p: 2.8993, G_pp: 0.5609
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 10.0000, G_p: 2.9581, G_pp: 0.4255
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 14.2510, G_p: 2.9900, G_pp: 0.3323
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 20.3092, G_p: 3.0081, G_pp: 0.2765
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 28.9427, G_p: 3.0208, G_pp: 0.2532
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 41.2463, G_p: 3.0337, G_pp: 0.2595
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 58.7802, G_p: 3.0516, G_pp: 0.2941
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 83.7678, G_p: 3.0790, G_pp: 0.3575
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 119.3777, G_p: 3.1209, G_pp: 0.4513
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 170.1254, G_p: 3.1829, G_pp: 0.5788
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 242.4462, G_p: 3.2722, G_pp: 0.7440
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1.0000, omega: 345.5107, G_p: 3.3979, G_pp: 0.9520
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 492.3883, G_p: 3.5717, G_pp: 1.2074
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 701.7038, G_p: 3.8078, G_pp: 1.5143
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 1.0000, omega: 1000.0000, G_p: 4.1245, G_pp: 1.8745
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0010, G_p: 0.0000, G_pp: 0.0091
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0014, G_p: 0.0000, G_pp: 0.0129
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0020, G_p: 0.0001, G_pp: 0.0184
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0029, G_p: 0.0002, G_pp: 0.0262
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0041, G_p: 0.0004, G_pp: 0.0374
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0059, G_p: 0.0008, G_pp: 0.0533
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.92 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0084, G_p: 0.0016, G_pp: 0.0759
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0119, G_p: 0.0032, G_pp: 0.1081
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 10.0000, omega: 0.0170, G_p: 0.0065, G_pp: 0.1538
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0242, G_p: 0.0131, G_pp: 0.2187
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0346, G_p: 0.0264, G_pp: 0.3101
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0492, G_p: 0.0529, G_pp: 0.4376
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.0702, G_p: 0.1044, G_pp: 0.6119
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.1000, G_p: 0.2008, G_pp: 0.8409
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.1425, G_p: 0.3692, G_pp: 1.1228
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.2031, G_p: 0.6346, G_pp: 1.4393
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.2894, G_p: 1.0057, G_pp: 1.7622
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.4125, G_p: 1.4804, G_pp: 2.0733
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 0.5878, G_p: 2.0695, G_pp: 2.3542
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 10.0000, omega: 0.8377, G_p: 2.7824, G_pp: 2.5539
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 1.1938, G_p: 3.5806, G_pp: 2.5995
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 1.7013, G_p: 4.3709, G_pp: 2.4511
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 2.4245, G_p: 5.0489, G_pp: 2.1351
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 3.4551, G_p: 5.5513, G_pp: 1.7319
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 4.9239, G_p: 5.8773, G_pp: 1.3294
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 7.0170, G_p: 6.0678, G_pp: 0.9841
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 10.0000, G_p: 6.1713, G_pp: 0.7145
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 14.2510, G_p: 6.2251, G_pp: 0.5158
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 20.3092, G_p: 6.2524, G_pp: 0.3753
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 10.0000, omega: 28.9427, G_p: 6.2662, G_pp: 0.2796
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 41.2463, G_p: 6.2733, G_pp: 0.2183
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 10.0000, omega: 58.7802, G_p: 6.2771, G_pp: 0.1844
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 10.0000, omega: 83.7678, G_p: 6.2797, G_pp: 0.1737
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 119.3777, G_p: 6.2824, G_pp: 0.1849
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 170.1254, G_p: 6.2866, G_pp: 0.2191
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 242.4462, G_p: 6.2942, G_pp: 0.2803
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.09 seconds
# 50176
# alpha: 10.0000, omega: 345.5107, G_p: 6.3085, G_pp: 0.3751
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 492.3883, G_p: 6.3354, G_pp: 0.5129
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 10.0000, omega: 701.7038, G_p: 6.3848, G_pp: 0.7057
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 10.0000, omega: 1000.0000, G_p: 6.4731, G_pp: 0.9670
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0010, G_p: 0.0000, G_pp: 0.0117
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0014, G_p: 0.0001, G_pp: 0.0167
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 0.0020, G_p: 0.0002, G_pp: 0.0237
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0029, G_p: 0.0003, G_pp: 0.0338
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0041, G_p: 0.0007, G_pp: 0.0482
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0059, G_p: 0.0014, G_pp: 0.0687
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0084, G_p: 0.0028, G_pp: 0.0978
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0119, G_p: 0.0057, G_pp: 0.1392
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0170, G_p: 0.0114, G_pp: 0.1980
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0242, G_p: 0.0231, G_pp: 0.2808
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 0.0346, G_p: 0.0462, G_pp: 0.3963
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0492, G_p: 0.0911, G_pp: 0.5544
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.0702, G_p: 0.1751, G_pp: 0.7627
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.1000, G_p: 0.3213, G_pp: 1.0205
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.1425, G_p: 0.5505, G_pp: 1.3133
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.2031, G_p: 0.8675, G_pp: 1.6209
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.2894, G_p: 1.2690, G_pp: 1.9374
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 0.4125, G_p: 1.7725, G_pp: 2.2644
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 0.5878, G_p: 2.4129, G_pp: 2.5701
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 0.8377, G_p: 3.1955, G_pp: 2.7794
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 1.1938, G_p: 4.0644, G_pp: 2.8135
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 1.7013, G_p: 4.9153, G_pp: 2.6370
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100.0000, omega: 2.4245, G_p: 5.6375, G_pp: 2.2842
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 3.4551, G_p: 6.1677, G_pp: 1.8443
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 4.9239, G_p: 6.5091, G_pp: 1.4107
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100.0000, omega: 7.0170, G_p: 6.7076, G_pp: 1.0411
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.10 seconds
# 50176
# alpha: 100.0000, omega: 10.0000, G_p: 6.8150, G_pp: 0.7532
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.11 seconds
# 50176
# alpha: 100.0000, omega: 14.2510, G_p: 6.8706, G_pp: 0.5411
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 100.0000, omega: 20.3092, G_p: 6.8987, G_pp: 0.3901
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100.0000, omega: 28.9427, G_p: 6.9128, G_pp: 0.2860
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# ...
# 50176
# alpha: 100000.0000, omega: 0.0041, G_p: 0.7199, G_pp: 1.1884
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.96 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 0.0059, G_p: 0.9929, G_pp: 1.3873
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0084, G_p: 1.3050, G_pp: 1.6109
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.89 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0119, G_p: 1.6837, G_pp: 1.8647
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0170, G_p: 2.1543, G_pp: 2.1308
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0242, G_p: 2.7314, G_pp: 2.3789
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.92 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 0.0346, G_p: 3.4201, G_pp: 2.5640
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0492, G_p: 4.1980, G_pp: 2.6241
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.0702, G_p: 4.9947, G_pp: 2.5046
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.1000, G_p: 5.7028, G_pp: 2.2044
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.1425, G_p: 6.2367, G_pp: 1.7951
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 0.2031, G_p: 6.5826, G_pp: 1.3758
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 0.2894, G_p: 6.7823, G_pp: 1.0133
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.4125, G_p: 6.8896, G_pp: 0.7294
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 0.5878, G_p: 6.9448, G_pp: 0.5186
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.04 seconds
# 50176
# alpha: 100000.0000, omega: 0.8377, G_p: 6.9726, G_pp: 0.3666
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 1.1938, G_p: 6.9865, G_pp: 0.2585
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 1.7013, G_p: 6.9933, G_pp: 0.1823
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 2.4245, G_p: 6.9967, G_pp: 0.1289
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 100000.0000, omega: 3.4551, G_p: 6.9984, G_pp: 0.0918
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 4.9239, G_p: 6.9992, G_pp: 0.0663
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 7.0170, G_p: 6.9996, G_pp: 0.0492
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 100000.0000, omega: 10.0000, G_p: 6.9998, G_pp: 0.0383
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0000, G_p: 0.0009, G_pp: 0.0450
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0000, G_p: 0.0018, G_pp: 0.0641
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.94 seconds
# Finished summing duplicates/eliminating zeros in 3.09 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0000, G_p: 0.0036, G_pp: 0.0912
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.88 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0000, G_p: 0.0072, G_pp: 0.1297
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0000, G_p: 0.0146, G_pp: 0.1840
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.96 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0001, G_p: 0.0292, G_pp: 0.2600
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0001, G_p: 0.0579, G_pp: 0.3643
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0001, G_p: 0.1120, G_pp: 0.5024
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0002, G_p: 0.2079, G_pp: 0.6741
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0002, G_p: 0.3608, G_pp: 0.8682
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 4.04 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0003, G_p: 0.5718, G_pp: 1.0650
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.87 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0005, G_p: 0.8244, G_pp: 1.2568
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0007, G_p: 1.1083, G_pp: 1.4601
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0010, G_p: 1.4397, G_pp: 1.6932
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0014, G_p: 1.8474, G_pp: 1.9518
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0020, G_p: 2.3515, G_pp: 2.2130
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.81 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0029, G_p: 2.9640, G_pp: 2.4436
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0041, G_p: 3.6840, G_pp: 2.5928
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.08 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0059, G_p: 4.4754, G_pp: 2.5973
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0084, G_p: 5.2521, G_pp: 2.4146
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0119, G_p: 5.9066, G_pp: 2.0683
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0170, G_p: 6.3742, G_pp: 1.6465
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.82 seconds
# Finished summing duplicates/eliminating zeros in 3.07 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0242, G_p: 6.6641, G_pp: 1.2423
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.93 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0346, G_p: 6.8268, G_pp: 0.9064
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0492, G_p: 6.9127, G_pp: 0.6489
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.0702, G_p: 6.9565, G_pp: 0.4600
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.1000, G_p: 6.9784, G_pp: 0.3245
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.10 seconds
# 50176
# alpha: 1000000.0000, omega: 0.1425, G_p: 6.9894, G_pp: 0.2283
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.91 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.2031, G_p: 6.9948, G_pp: 0.1605
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.2894, G_p: 6.9974, G_pp: 0.1128
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.83 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.4125, G_p: 6.9987, G_pp: 0.0793
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.92 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 0.5878, G_p: 6.9994, G_pp: 0.0559
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.93 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 0.8377, G_p: 6.9997, G_pp: 0.0395
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.90 seconds
# Finished summing duplicates/eliminating zeros in 3.08 seconds
# 50176
# alpha: 1000000.0000, omega: 1.1938, G_p: 6.9998, G_pp: 0.0282
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 1.7013, G_p: 6.9999, G_pp: 0.0204
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 2.4245, G_p: 7.0000, G_pp: 0.0153
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.08 seconds
# 50176
# alpha: 1000000.0000, omega: 3.4551, G_p: 7.0000, G_pp: 0.0120
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.84 seconds
# Finished summing duplicates/eliminating zeros in 3.05 seconds
# 50176
# alpha: 1000000.0000, omega: 4.9239, G_p: 7.0000, G_pp: 0.0103
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.85 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 7.0170, G_p: 7.0000, G_pp: 0.0099
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Finished constructing entries in 3.86 seconds
# Finished summing duplicates/eliminating zeros in 3.06 seconds
# 50176
# alpha: 1000000.0000, omega: 10.0000, G_p: 7.0000, G_pp: 0.0107

# %%
figure = plt.figure(figsize=(8,6))
alphas = [0.001, 1/3, 1, 10, 100]
colours = ['b', 'g', 'r', 'c', 'm']
for i, alpha in enumerate(alphas):
    plt.loglog(omega_list_fig4_top[i*40:(i+1) * 40], G_p_list_fig4_top[i*40:(i+1) * 40], label=f"G' (alpha={alpha:.3f})", color=colours[i])
    plt.loglog(omega_list_fig4_top[i*40:(i+1) * 40], G_pp_list_fig4_top[i*40:(i+1) * 40], linestyle='--', label=f"G'' (alpha={alpha:.3f})", color=colours[i])
plt.xlabel(r"$\omega$")
plt.ylabel(r"$G', G''$")
plt.xlim(1e-3, 1e3)
plt.ylim(1e-3, 1e1)
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.title(r"Dynamic shear moduli for sticky model with $M=2, N_b=15$, various $\alpha/\beta$ (replicating fig. 4 top)")
plt.legend()
plt.grid()
plt.show()

# %%
figure = plt.figure(figsize=(8,6))
alphas = [1e3, 1e4, 1e5, 1e6]
colours = ['m', 'c', 'y', 'k']
for i, alpha in enumerate(alphas):
    plt.loglog(omega_list_fig4_bottom[i*40:(i+1) * 40], G_p_list_fig4_bottom[i*40:(i+1) * 40], label=f"G' (alpha={format(alpha, '.0e')})", color=colours[i])
    plt.loglog(omega_list_fig4_bottom[i*40:(i+1) * 40], G_pp_list_fig4_bottom[i*40:(i+1) * 40], linestyle='--', label=f"G'' (alpha={format(alpha, '.0e')})", color=colours[i])
plt.xlabel(r"$\omega$")
plt.ylabel(r"$G', G''$")
plt.xlim(1e-5, 1e1)
plt.ylim(1e-3, 1e1)
plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
plt.title(r"Dynamic shear moduli for sticky model with $M=2, N_b=15$, various $\alpha/\beta$ (replicating fig. 4 bottom)")
plt.legend()
plt.grid()
plt.show()

# %%
# FIG. 7 top

N_as = [2, 3, 5, 9]
omegas = np.logspace(-3, 3, 40)
omega_list_fig7_top = []
G_p_list_fig7_top = []
G_pp_list_fig7_top = []

for N_a in N_as:
    for omega in omegas:
        M = (N_b - 1) // N_a + 1
        W = generate_W(N_a=N_a, alpha=100, beta=1) # beta is always 1 (in units of 1/beta)
        B = B_tensor(M=M, N_b=9)
        A, b = construct_Ab(omega, B, W, N_k=128, N_a=N_a, s_max=2**N_a-1, N_b=9, M=M)
        x = spsolve(A, b)
        G_p, G_pp = dynamic_shear_moduli(x, 100, 1, 2**8-1, M, 9)
        print(f"N_a: {N_a}, omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}")
        omega_list_fig7_top.append(omega)
        G_p_list_fig7_top.append(G_p)
        G_pp_list_fig7_top.append(G_pp)
        del A, b, x, G_p, G_pp, W, B

# FIG. 7 bottom

N_as = [2, 3, 5, 9]
omegas = np.logspace(-3, 3, 40)
omega_list_fig7_bottom = []
G_p_list_fig7_bottom = []
G_pp_list_fig7_bottom = []

for N_a in N_as:
    for omega in omegas:
        M = (N_b - 1) // N_a + 1
        W = generate_W(N_a=N_a, alpha=10000, beta=1) # beta is always 1 (in units of 1/beta)
        B = B_tensor(M=M, N_b=9)
        A, b = construct_Ab(omega, B, W, N_k=128, N_a=N_a, s_max=2**N_a-1, N_b=9, M=M)
        x = spsolve(A, b)
        G_p, G_pp = dynamic_shear_moduli(x, 10000, 1, 2**8-1, M, 9)
        print(f"N_a: {N_a}, omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}")
        omega_list_fig7_bottom.append(omega)
        G_p_list_fig7_bottom.append(G_p)
        G_pp_list_fig7_bottom.append(G_pp)
        del A, b, x, G_p, G_pp, W, B
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 12
#      10 for omega in omegas:
#      11     M = (N_b - 1) // N_a + 1
# ---> 12     W = generate_W(N_a=N_a, alpha=100, beta=1) # beta is always 1 (in units of 1/beta)
#      13     B = B_tensor(M=M, N_b=9)
#      14     A, b = construct_Ab(omega, B, W, N_k=128, N_a=N_a, s_max=2**N_a-1, N_b=9, M=M)
#
# TypeError: generate_W() got an unexpected keyword argument 'alpha'
