# %% [markdown]
# # Multiple Sticker Model
# Based off Indei & Takimoto (2010), we're gonna implement what they did and compare it to our model. The association and dissociation rates we will have to calculate ourselves from the simulations, so we can start with getting the same plots as they generate.
#
# We make the same assumption that the association and dissociation rates of all the stickers is the same, $\alpha, \beta$.
#
# Check out sticky_model.ipynb for the process of constructing this model. This notebook is just for matching it to our experimental data.

# %% [markdown]
# ## Generating $\mathbf{K}(l)$

# %%
import numpy as np

def recursive_K(l, alpha, beta):
    if l == 1:
        return np.array([[1, beta],[alpha, 1]])
    else:
        tl = recursive_K(l-1, alpha, beta)
        tr = beta * np.identity(2 ** (l-1))
        bl = alpha * np.identity(2 ** (l-1))
        br = recursive_K(l-1, alpha, beta)
        return np.block([[tl, tr],
                          [bl, br]])

def recursive_K_list(l, alpha_list, beta_list):
    if l == 1:
        return np.array([[1, beta_list[0]],[alpha_list[0], 1]])
    else:
        tl = recursive_K_list(l-1, alpha_list[:-1], beta_list[:-1])
        tr = beta_list[l-1] * np.identity(2 ** (l-1))
        bl = alpha_list[l-1] * np.identity(2 ** (l-1))
        br = recursive_K_list(l-1, alpha_list[:-1], beta_list[:-1])
        return np.block([[tl, tr],
                          [bl, br]])

# %% [markdown]
# ## Generating $\mathbf W(N_a)$

# %%
# N_a is the total number of stickers on a chain
def generate_W(N_a, alpha, beta):
    K_N_a = recursive_K(N_a, alpha, beta)
    K_upper = np.triu(K_N_a, 1)
    K_lower = np.tril(K_N_a, -1)
    
    W_diagonal = np.diagflat(-np.sum(K_N_a, axis=0)+1)

    return K_upper + K_lower + W_diagonal

def generate_W_lists(N_a, alpha_lit, beta_list):
    if len(alpha_lit) != len(beta_list) or len(alpha_lit) != N_a:
        raise ValueError("Incorrect number of association/dissociation parameters.")
    K_N_a = recursive_K_list(N_a, alpha_lit, beta_list)
    K_upper = np.triu(K_N_a, 1)
    K_lower = np.tril(K_N_a, -1)
    
    W_diagonal = np.diagflat(-np.sum(K_N_a, axis=0)+1)

    return K_upper + K_lower + W_diagonal

# %%
def extract_n_s(s, M, N_b):
    N_a = (N_b - 1) // M + 1
    if N_a < M:
        raise ValueError("N_a must be greater than or equal to M.")
    
    n_s = np.zeros(M * (N_a-1) + 1, dtype=int)

    index = 0
    while True:
        n_s[index] = s & 1
        s = s >> 1
        if s == 0:
            break
        if index >= M * (N_a-1):
            raise ValueError(f"s is too large to fit in the specified number of stickers and spacing, s^max = {2 ** N_a - 1}.")
        index += M
    return n_s

# %%
# Note: negating 0 gives -1, we have to add some int() typecasts
def generate_B(s, M, N_b):
    if (N_b-1) % M != 0:
        raise ValueError("N_b-1 must be divisible by M.")
    n_s = extract_n_s(s, M, N_b)
    B = np.zeros((N_b-1, N_b-1))

    for i, pair in enumerate(zip(n_s[:-1], n_s[1:])):
        if i != 0: # a_i
            B[i, i-1] = -1 * int(pair[0]==0)
        if i != N_b - 2: # c_i
            B[i, i+1] = -1 * int(pair[1]==0)
        # b_i
        B[i, i] = (int(pair[0]==0) or int(pair[1]==0)) + (int(pair[0]==0) and int(pair[1]==0))

    return B

# %% [markdown]
# # Solving equations for $h_{k,l}^s, g_{k,l}^s$
# We need to solve for coefficients $h_{k,l}^s, g_{k,l}^s$ governed by equation 25a
# $$
# - \omega h_{k,l}^s + \frac{k_b}{\zeta} \sum_{j=1}^{N_b-1}(B_{k,j}^sg_{j,l}^s + B_{l,j}^sg_{k,j}^s) = \sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime, s} g_{k,l}^{s^\prime}
# $$
# and 25b
# $$
# \omega g_{k,l}^s-\omega \delta_{k,l} + \frac{k_b}{\zeta}\sum_{j=1}^{N_b-1}(B_{k,j}^sh_{j,l}^s+B_{l,j}^sh_{k,j}^s)=\sum_{s^\prime=0}^{s_\text{max}}W_{s^\prime,s}h_{k,l}^{s^\prime}
# $$

# %%
from scipy.sparse import lil_matrix, csr_matrix, csc_matrix, coo_matrix
from scipy.sparse.linalg import LinearOperator
from time import time

"""
Linear operator form of A, does not need to store/manipulate the full matrix. Intended for use with iterative solvers like GMRES.

Uses the same indexing scheme as the full matrix, check out construct_Ab for more details.

Args:
    - x: vectorized g and h, stacked
    - omega: omega value to calculate shear dynamic moduli -- each omega value gives us one value of G' and G'' each
    - B: (s_max + 1) x (N_b - 1) x (N_b - 1) bead connectivity matrix
    - W: (s_max + 1) x (s_max + 1) association state transition matrix
    - k_b: spring constant along backbone beads
    - zeta: friction constant from Langevin equation (also dimensionless friction constant, they are interchangeable)
    - N_k: number of Kuhn steps in one chain, used if dimensionless (i.e. if k_b is none, replaces k_b)
    - N_b: number of beads in one chain
    - M: spacing of stickers
    - N_a: number of stickers in one chain (if None, is calculated)
    - s_max: maximum association state (if None, is calculated)

Returns:
    - Ax: result of applying linear operator A to vector x

"""
def A_operator(x, omega, B, W, k_b=None, zeta=1e-5, N_k=128, N_b=31, M=5, N_a=7, s_max=None):
    if N_a == None:
        N_a = (N_b - 1) // M + 1
    
    if s_max == None:
        s_max = 2**N_a - 1
    
    vectorize_length = (s_max + 1) * (N_b - 1) * (N_b - 1)

    if k_b == None:
        k_b_zeta = 3/(zeta * N_k)
    else:
        k_b_zeta = k_b/zeta


    Ax = np.zeros_like(x)

    # this is pass by reference btw
    g = x[:vectorize_length].reshape(s_max+1, N_b-1, N_b-1)
    h = x[vectorize_length:].reshape(s_max+1, N_b-1, N_b-1)

    Ax_g = Ax[:vectorize_length].reshape(s_max+1, N_b-1, N_b-1)
    Ax_h = Ax[vectorize_length:].reshape(s_max+1, N_b-1, N_b-1)

    Wg = np.tensordot(W.T, g, axes=(1,0))
    Wh = np.tensordot(W.T, h, axes=(1,0))

    BT = B.transpose(0, 2, 1)

    Bg_left = B @ g
    Bg_right = g @ BT

    Bh_left = B @ h
    Bh_right = h @ BT

    Ax_g += -omega * h + k_b_zeta * Bg_left + k_b_zeta * Bg_right - Wg
    Ax_h += omega * g + k_b_zeta * Bh_left + k_b_zeta * Bh_right - Wh

    return Ax

# %%
"""
Construct coupling matrix A and constant RHS b such that we can solve an equation Ax = b to get values of g, h
In this form, x is stacked vectorized g and h. Each row of A encodes an equation.
A encodes equation 25a in the first vectorize_length rows, and 25b in the second vectorize_length rows.

We additionally need B^s_{k,l} and W_{s', s} matrices. W isn't a problem, but B needs to be composed into a 
tensor for each valid value of s.

Generating with COO sparse matrix is the fastest out of what I tested.

Args:
    - omega: omega value to calculate shear dynamic moduli -- each omega value gives us one value of G' and G'' each
    - B: (s_max + 1) x (N_b - 1) x (N_b - 1) bead connectivity matrix
    - W: (s_max + 1) x (s_max + 1) association state transition matrix
    - k_b: spring constant along backbone beads
    - zeta: friction constant from Langevin equation (also dimensionless friction constant, they are interchangeable)
    - N_k: number of Kuhn steps in one chain, used if dimensionless (i.e. if k_b is none, replaces k_b)
    - N_b: number of beads in one chain
    - M: spacing of stickers
    - N_a: number of stickers in one chain (if None, is calculated)
    - s_max: maximum association state (if None, is calculated)
    - pbar: optional tqdm progress bar to update during construction (single global bar)
Returns:
    - A: matrix A encoding equations 25a and 25b to be applied to vectorized g and h.
    - b: RHS constants from equations 25a and 25b
"""
def construct_Ab(omega, B, W, k_b=None, zeta=1e-5, N_k=128, N_b=15, M=2, N_a=8, s_max=None, pbar=None, verbose=True):
    start = time()

    if N_a == None:
        N_a = (N_b - 1) // M + 1
    
    if s_max == None:
        s_max = 2**N_a - 1
    
    vectorize_length = (s_max + 1) * (N_b - 1) * (N_b - 1)

    if k_b == None:
        k_b_zeta = 3/(zeta * N_k)
        if verbose:
            print(f"Using dimensionless k_b = 1/N_k = {1/N_k}, zeta = {zeta}, so k_b/zeta = {k_b_zeta}")
    else:
        k_b_zeta = k_b/zeta
        if verbose:
            print(f"Using k_b = {k_b}, zeta = {zeta}, so k_b/zeta = {k_b_zeta}")

    b = np.zeros((2 * vectorize_length, 1))

    for s in range(s_max + 1):
        for k in range (1, N_b):
            for l in range (1, N_b):
                # for 25b, b = \omega \delta_{k,l}
                if k == l:
                    b[(s_max+1)*(N_b-1)**2 + s*(N_b-1)**2 + (k-1)*(N_b-1) + (l-1), 0] += omega
    A = LinearOperator((2 * vectorize_length, 2 * vectorize_length), matvec=lambda x: A_operator(x, omega, B, W, k_b=k_b, zeta=zeta, N_k=N_k, N_b=N_b, M=M, N_a=N_a, s_max=s_max))
    # print(f"Constructed A and b in {time() - start:.2f} seconds.")
    
    return A, b

# %%
def B_tensor(M=2, N_b=15):
    N_a = (N_b - 1) // M + 1
    s_max = 2**N_a - 1
    B = np.zeros((s_max + 1, N_b-1, N_b-1))
    for s in range(2**N_a):
        B_mat = generate_B(s=s, M=M, N_b=N_b)
        B[s] = B_mat
    return B
# B_tensor()

# %%
def count_associated(s, M=2, N_b=15):
    return np.sum(extract_n_s(s, M, N_b))

# n_c is density of chains
def nu_s(s, alpha, beta, M, N_b, n_c=1):
    N_a = (N_b - 1) // M + 1
    N_s = count_associated(s, M, N_b)
    return alpha**N_s * beta**(N_a - N_s) / (alpha + beta)**N_a * n_c
    

def dynamic_shear_moduli(x, alpha, beta, s_max, M, N_b, k_B=1, T=1, n_c=1):
    length = len(x)//2

    g = np.reshape(x[:length], (s_max+1, N_b-1, N_b-1))
    h = np.reshape(x[length:], (s_max+1, N_b-1, N_b-1))

    G_p = 0
    G_pp = 0 
    for s in range(s_max+1):
        for k in range(N_b-1):
            G_p += k_B*T* nu_s(s, alpha, beta, M, N_b, n_c)*g[s, k, k]
            G_pp += k_B*T* nu_s(s, alpha, beta, M, N_b, n_c)*h[s, k, k]

    return G_p, G_pp

# %%
from tqdm.notebook import tqdm
from scipy.sparse.linalg import spsolve, lgmres, gmres
from joblib import Parallel, delayed
from time import time
from threadpoolctl import threadpool_limits

def solve_omega(omega, thread_limit=2, alpha=1, beta=1, k_b=1.72, zeta=25, N_k=None, N_b=31, N_a=7, M=5, n_c=0.0274, verbose=True, x0=None):
    s_max = 2**N_a - 1

    # generating matrices
    B = B_tensor(M=M, N_b=N_b)
    W = generate_W(N_a=N_a, alpha=alpha, beta=beta)

    with threadpool_limits(limits=thread_limit):
        start = time()
        A, b = construct_Ab(omega, B, W, k_b=k_b, zeta=zeta, N_k=N_k, N_b=N_b, M=M, N_a=N_a, s_max=s_max, verbose=verbose)
        # print("Matrix constructed.")

        x, info = lgmres(A, b, x0=x0, maxiter=1000)
        if info != 0:
            if verbose:
                print(f"LGMRES did not converge, info = {info}, trying again GMRES")
            x, info = gmres(A, b, x0=x0)
        x0 = x  # Update x0 for the next iteration (whichever one that is, not necessarily the next omega exactly)
        if verbose:
            print("Solved for x w/ LGMRES")
        assert info == 0, f"Did not converge, info = {info}"
        
        G_p, G_pp = dynamic_shear_moduli(x, alpha=alpha, beta=beta, s_max=s_max, M=M, N_b=N_b, k_B=1, T=1, n_c=n_c)
        if verbose:
            print(f"Omega: {omega:.4f}, G_p: {G_p:.4f}, G_pp: {G_pp:.4f}, time taken: {time() - start:.2f} seconds")

        return omega, G_p, G_pp, x

# %%
def solve_spectrum(omegas, n_jobs=10, thread_limit=2, alpha=1, beta=1, k_b=1.72, zeta=25, N_k=None, N_b=31, N_a=7, M=5, n_c=0.0274, verbose=True, x0=None):
    results = Parallel(n_jobs=n_jobs)(
        delayed(solve_omega)(thread_limit=thread_limit, omega=omega, alpha=alpha, beta=beta, k_b=k_b, zeta=zeta, N_k=N_k, N_b=N_b, N_a=N_a, M=M, n_c=n_c, verbose=verbose, x0=x0) for omega in omegas
    )
    
    results_sorted = sorted(results, key=lambda t: t[0])

    # unpack
    omegas, G_p_list, G_pp_list, x0_list = zip(*results_sorted)

    # convert to numpy arrays, faster for plotting/processing
    omegas = np.array(omegas)
    G_p_list = np.array(G_p_list)
    G_pp_list = np.array(G_pp_list)

    return omegas, G_p_list, G_pp_list, x0_list

# %%
# N_k = 128
# zeta_tilde = 1e-5
# N_b = 15

# t_rouse = N_k * zeta_tilde * N_b**2 / np.pi**2
# print("Rouse time:", t_rouse)

# %% [markdown]
# ## Trying different values of alpha, beta

# %%
import pandas as pd
A_lifetime_offtime_list = [(80,    7.27,    5.60), 
                           (80,   14.65,    1.02), 
                           (90,   10.38,   16.65), 
                           (90,   16.35,    1.66), 
                           (100,  16.79,   55.33), 
                           (100,  29.40,    6.99),
                           (110,  28.19,  190.89), 
                           (110,  70.54,   21.67), 
                           (120,  36.24,  774.71), 
                           (120, 142.14,   81.39), 
                           (130,  50.43, 3646.96), 
                           (130, 184.95,  386.61)]

# n = 20
# A_list = np.zeros(n)
# alpha_list = np.logspace(-3, 3, 20)
# beta_list = np.logspace(3, -3, 20)

# verbose = False

# A_alpha_beta_list =  zip(A_list, alpha_list, beta_list)

x0 = None

# %%
for A, alpha, beta in A_alpha_beta_list:
    omegas = np.logspace(-4, 2, 20)
    # omegas_scheduler = np.zeros(20)
    # omegas_scheduler[:10] = omegas[:10]
    # omegas_scheduler[10:] = omegas[:9:-1]
    omegas_scheduler = omegas
    # print(omegas_scheduler)
    start = time()
    print(f"Started solving for A={A}, alpha={alpha}, beta={beta}...")
    omegas, G_p_list, G_pp_list, x0_list = solve_spectrum(omegas_scheduler, n_jobs=10, thread_limit=2, alpha=alpha, beta=beta, N_b=31, N_a=7, M=5, n_c=0.0274, verbose=verbose, x0=x0)
    x0 = x0_list[-1]  # Use the last solution as the initial guess for the next iteration
    df = pd.DataFrame({
        'omega': omegas,
        'G_p': G_p_list,
        'G_pp': G_pp_list
    })
    print(f"Completed for A={A}, alpha={alpha}, beta={beta} in {time() - start:.2f} seconds.")
    if verbose:
        print(f"Alpha: {alpha}, Beta: {beta}")
        print("G' values:", G_p_list)
        print("G'' values:", G_pp_list)

    df.to_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_alpha_{alpha}_beta_{beta}.csv', index=False)

# %%
import pandas as pd

paper_sticky_model_G_p_alpha_1 = pd.read_csv("data/comparison/sticky_Gp_alpha_1.csv", names=["omega", "G'"])
paper_sticky_model_G_pp_alpha_1 = pd.read_csv("data/comparison/sticky_Gpp_alpha_1.csv", names=["omega", "G''"])
my_sticky_model_moduli_alpha_1 = pd.read_csv("data/comparison/my_sticky_model_alpha_1.csv")
print(paper_sticky_model_G_p_alpha_1.head())
# Out:
#       omega        G'
# 0  0.020515  0.001256
# 1  0.023709  0.001674
# 2  0.027042  0.002182
# 3  0.030844  0.002837
# 4  0.035180  0.003688

# %%
import matplotlib.pyplot as plt

processed_As = set()
for A, alpha, beta in A_alpha_beta_list:
    if A in processed_As:
        continue
    processed_As.add(A)

for current_A in processed_As:
    figure = plt.figure(figsize=(16,12))
    for A, alpha, beta in A_alpha_beta_list:
        if A == current_A:
            df = pd.read_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_alpha_{alpha}_beta_{beta}.csv')
            plt.loglog(df['omega'], df['G_p'], label=f"G' (A={A}, alpha={alpha}, beta={beta})")
            plt.loglog(df['omega'], df['G_pp'], linestyle='--', label=f"G'' (A={A}, alpha={alpha}, beta={beta})")
    # plt.loglog(paper_sticky_model_G_p_alpha_1["omega"], paper_sticky_model_G_p_alpha_1["G'"], color='r', label="G'' (paper data)")
    # plt.loglog(paper_sticky_model_G_pp_alpha_1["omega"], paper_sticky_model_G_pp_alpha_1["G''"], color='r', linestyle='--', label="G'' (paper data)") 
    plt.title(r"Dynamic shear moduli for sticky model with $\alpha/\beta=1, M=2, N_b=15$")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$G', G''$")
    plt.xlim(1e-4, 1e2)
    plt.ylim(1e-3, 1e1)
    plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
    plt.legend()
    plt.grid()  
    plt.show()
# Out:
# /tmp/ipykernel_196598/3579263312.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Testing different $k_b$ and $\zeta$ values for the sticky model

# %%
import pandas as pd
A_kb_zeta_list = []
for k_b in [0.43, 0.86,1.72, 3.44, 5.16]:
    for zeta in [5, 10, 25, 50, 75]:
        A_kb_zeta_list.append((0.0, k_b, zeta))

verbose = False
alpha = 0.001
beta = 1
x0 = None

for A, k_b, zeta in A_kb_zeta_list:
    omegas = np.logspace(-4, 2, 20)
    # omegas_scheduler = np.zeros(20)
    # omegas_scheduler[:10] = omegas[:10]
    # omegas_scheduler[10:] = omegas[:9:-1]
    omegas_scheduler = omegas
    # print(omegas_scheduler)
    start = time()
    print(f"Started solving for A={A}, k_b={k_b}, zeta={zeta}...")
    omegas, G_p_list, G_pp_list, x0_list = solve_spectrum(omegas_scheduler, n_jobs=6, thread_limit=2, alpha=alpha, beta=beta, k_b=k_b, zeta=zeta, N_b=31, N_a=7, M=5, n_c=0.0274, verbose=verbose, x0=x0)
    x0 = x0_list[-1]  # Use the last solution as the initial guess for the next iteration
    df = pd.DataFrame({
        'omega': omegas,
        'G_p': G_p_list,
        'G_pp': G_pp_list
    })
    print(f"Completed for A={A}, k_b={k_b}, zeta={zeta} in {time() - start:.2f} seconds.")
    if verbose:
        print(f"K_b: {k_b}, Zeta: {zeta}")
        print("G' values:", G_p_list)
        print("G'' values:", G_pp_list)

    df.to_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_k_b_{k_b}_zeta_{zeta}_alpha_{alpha}_beta_{beta}.csv', index=False)
# Out:
# Started solving for A=0.0, k_b=0.43, zeta=5...
# Completed for A=0.0, k_b=0.43, zeta=5 in 14.88 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=10...
# Completed for A=0.0, k_b=0.43, zeta=10 in 22.32 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=25...
# Completed for A=0.0, k_b=0.43, zeta=25 in 31.13 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=50...
# Completed for A=0.0, k_b=0.43, zeta=50 in 35.47 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=75...
# Completed for A=0.0, k_b=0.43, zeta=75 in 33.97 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=5...
# Completed for A=0.0, k_b=0.86, zeta=5 in 11.66 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=10...
# Completed for A=0.0, k_b=0.86, zeta=10 in 16.32 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=25...
# Completed for A=0.0, k_b=0.86, zeta=25 in 24.98 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=50...
# Completed for A=0.0, k_b=0.86, zeta=50 in 29.83 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=75...
# Completed for A=0.0, k_b=0.86, zeta=75 in 38.46 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=5...
# Completed for A=0.0, k_b=1.72, zeta=5 in 9.81 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=10...
# Completed for A=0.0, k_b=1.72, zeta=10 in 12.18 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=25...
# Completed for A=0.0, k_b=1.72, zeta=25 in 19.45 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=50...
# Completed for A=0.0, k_b=1.72, zeta=50 in 25.19 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=75...
# Completed for A=0.0, k_b=1.72, zeta=75 in 32.85 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=5...
# Completed for A=0.0, k_b=3.44, zeta=5 in 8.40 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=10...
# Completed for A=0.0, k_b=3.44, zeta=10 in 9.46 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=25...
# Completed for A=0.0, k_b=3.44, zeta=25 in 13.70 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=50...
# Completed for A=0.0, k_b=3.44, zeta=50 in 19.88 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=75...
# Completed for A=0.0, k_b=3.44, zeta=75 in 21.58 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=5...
# Completed for A=0.0, k_b=5.16, zeta=5 in 7.96 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=10...
# Completed for A=0.0, k_b=5.16, zeta=10 in 9.64 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=25...
# Completed for A=0.0, k_b=5.16, zeta=25 in 11.28 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=50...
# Completed for A=0.0, k_b=5.16, zeta=50 in 16.25 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=75...
# Completed for A=0.0, k_b=5.16, zeta=75 in 21.15 seconds.

# %%
import matplotlib.pyplot as plt

alpha = 0.001
beta = 1
A = 0.0

processed_kbs = set()
for A, kb, zeta in A_kb_zeta_list:
    if kb in processed_kbs:
        continue
    processed_kbs.add(kb)

for current_k_b in processed_kbs:
    figure = plt.figure(figsize=(16,12))
    for A, k_b, zeta in A_kb_zeta_list:
        if k_b == current_k_b:
            df = pd.read_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_k_b_{k_b}_zeta_{zeta}_alpha_{alpha}_beta_{beta}.csv')
            plt.loglog(df['omega'], df['G_p'], label=f"G' (A={A}, k_b={k_b}, zeta={zeta})")
            plt.loglog(df['omega'], df['G_pp'], linestyle='--', label=f"G'' (A={A}, k_b={k_b}, zeta={zeta})")
    # plt.loglog(paper_sticky_model_G_p_alpha_1["omega"], paper_sticky_model_G_p_alpha_1["G'"], color='r', label="G'' (paper data)")
    # plt.loglog(paper_sticky_model_G_pp_alpha_1["omega"], paper_sticky_model_G_pp_alpha_1["G''"], color='r', linestyle='--', label="G'' (paper data)") 
    plt.title(r"Dynamic shear moduli for sticky model with $\alpha = 0.001, \beta = 1, M=5, N_b=31$")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$G', G''$")
    plt.xlim(1e-4, 1e2)
    plt.ylim(1e-3, 1e1)
    plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
    plt.legend()
    plt.grid()  
    plt.show()

# %% [markdown]
# ## Let's match the furthest graph to the right in Fig 4

# %%
alpha_list = [0.001, 0.002, 0.005, 0.01, 0.02, 0.05, 0.1]
omegas_list, G_p_list_list, G_pp_list_list, _ = [], [], [], []
for i, alpha in enumerate(alpha_list):
    omegas, G_p_list, G_pp_list, _ = solve_spectrum(np.logspace(1, 6, 20), n_jobs=6, thread_limit=2, alpha=alpha, beta=1, k_b=None, zeta=1e-5, N_k=128, N_b=31, N_a=7, M=5, n_c=1, verbose=True, x0=x0)
    omegas_list.append(omegas)
    G_p_list_list.append(G_p_list)
    G_pp_list_list.append(G_pp_list)
# Out:
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Solved for x w/ LGMRES
# Omega: 206.9138, G_p: 1
seconds
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Solved for x w/ LGMRES
# Omega: 26366.5090, G_p: 25.9160, G_pp: 8.1441, time taken: 0.41 seconds
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Solved for x w/ LGMRES
# Omega: 14384.4989, G_p: 21.1761, G_pp: 10.3155, time taken: 0.56 seconds
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Solved for x w/ LGMRES
# Omega: 88586.6790, G_p: 29.5283, G_pp: 3.0353, time taken: 0.26 seconds
# Solved for x w/ LGMRES
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Solved for x w/ LGMRES
# Omega: 162377.6739, G_p: 29.8565, G_pp: 1.6870, time taken: 0.25 seconds
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Omega: 48329.3024, G_p: 28.5210, G_pp: 5.2458, time taken: 0.55 seconds
# Solved for x w/ LGMRES
# Using dimensionless k_b = 1/N_k = 0.0078125, zeta = 1e-05, so k_b/zeta = 2343.75
# Omega: 297635.1442, G_p: 29.9570, G_pp: 0.9255, time taken: 0.23 seconds
# Solved for x w/ LGMRES
# Omega: 545559.4781, G_p: 29.9872, G_pp: 0.5058, time taken: 0.22 seconds
# Solved for x w/ LGMRES
# Omega: 1000000.0000, G_p: 29.9962, G_pp: 0.2761, time taken: 0.28 seconds
# Solved for x w/ LGMRES
# Omega: 33.5982, G_p: 0.6783, G_pp: 0.9517, time taken: 9.41 seconds
# Solved for x w/ LGMRES
# Omega: 18.3298, G_p: 0.4187, G_pp: 0.6660, time taken: 14.22 seconds
# Solved for x w/ LGMRES
# Omega: 10.0000, G_p: 0.2657, G_pp: 0.4406, time taken: 21.68 seconds

# %%
for i, alpha in enumerate(alpha_list):
    plt.loglog(omegas_list[i], G_p_list_list[i], label=f"G' (alpha={alpha})")
    plt.loglog(omegas_list[i], G_pp_list_list[i], linestyle='--', label=f"G'' (alpha={alpha})")
    # plt.loglog(paper_sticky_model_G_p_alpha_1["omega"], paper_sticky_model_G_p_alpha_1["G'"], color='r', label="G'' (paper data)")
    # plt.loglog(paper_sticky_model_G_pp_alpha_1["omega"], paper_sticky_model_G_pp_alpha_1["G''"], color='r', linestyle='--', label="G'' (paper data)") 
    plt.title(f"Dynamic shear moduli for sticky model with alpha = {alpha}, beta = 1, M=5, N_b=31")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$G', G''$")
    # plt.xlim(1e-2, 1e4)
    # plt.ylim(1e-3, 1e1)
    plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
    plt.legend()
    plt.grid()  
    plt.show()

# %% [markdown]
# So this is a MUCH larger $k_b/\zeta$ value than we had previously, at 2343.75 vs 0.0688. Let's try higher values of this prefactor,

# %%
import pandas as pd
A_kb_zeta_list = []
for k_b in [0.43, 0.86,1.72, 3.44, 5.16]:
    for zeta in [1/200, 1/100, 1/500]:
        A_kb_zeta_list.append((0.0, k_b, zeta))

verbose = False
alpha = 0.001
beta = 1
x0 = None

for A, k_b, zeta in A_kb_zeta_list:
    omegas = np.logspace(-2, 4, 20)
    # omegas_scheduler = np.zeros(20)
    # omegas_scheduler[:10] = omegas[:10]
    # omegas_scheduler[10:] = omegas[:9:-1]
    omegas_scheduler = omegas
    # print(omegas_scheduler)
    start = time()
    print(f"Started solving for A={A}, k_b={k_b}, zeta={zeta}...")
    omegas, G_p_list, G_pp_list, x0_list = solve_spectrum(omegas_scheduler, n_jobs=6, thread_limit=2, alpha=alpha, beta=beta, k_b=k_b, zeta=zeta, N_b=31, N_a=7, M=5, n_c=0.0274, verbose=verbose, x0=x0)
    x0 = x0_list[-1]  # Use the last solution as the initial guess for the next iteration
    df = pd.DataFrame({
        'omega': omegas,
        'G_p': G_p_list,
        'G_pp': G_pp_list
    })
    print(f"Completed for A={A}, k_b={k_b}, zeta={zeta} in {time() - start:.2f} seconds.")
    if verbose:
        print(f"K_b: {k_b}, Zeta: {zeta}")
        print("G' values:", G_p_list)
        print("G'' values:", G_pp_list)

    df.to_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_k_b_{k_b}_zeta_{zeta}_alpha_{alpha}_beta_{beta}.csv', index=False)
# Out:
# Started solving for A=0.0, k_b=0.43, zeta=0.005...
# Completed for A=0.0, k_b=0.43, zeta=0.005 in 9.48 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=0.01...
# Completed for A=0.0, k_b=0.43, zeta=0.01 in 8.11 seconds.
# Started solving for A=0.0, k_b=0.43, zeta=0.002...
# Completed for A=0.0, k_b=0.43, zeta=0.002 in 14.62 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=0.005...
# Completed for A=0.0, k_b=0.86, zeta=0.005 in 12.91 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=0.01...
# Completed for A=0.0, k_b=0.86, zeta=0.01 in 9.98 seconds.
# Started solving for A=0.0, k_b=0.86, zeta=0.002...
# Completed for A=0.0, k_b=0.86, zeta=0.002 in 20.14 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=0.005...
# Completed for A=0.0, k_b=1.72, zeta=0.005 in 17.74 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=0.01...
# Completed for A=0.0, k_b=1.72, zeta=0.01 in 13.62 seconds.
# Started solving for A=0.0, k_b=1.72, zeta=0.002...
# Completed for A=0.0, k_b=1.72, zeta=0.002 in 27.68 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=0.005...
# Completed for A=0.0, k_b=3.44, zeta=0.005 in 25.20 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=0.01...
# Completed for A=0.0, k_b=3.44, zeta=0.01 in 18.71 seconds.
# Started solving for A=0.0, k_b=3.44, zeta=0.002...
# Completed for A=0.0, k_b=3.44, zeta=0.002 in 39.96 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=0.005...
# Completed for A=0.0, k_b=5.16, zeta=0.005 in 32.01 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=0.01...
# Completed for A=0.0, k_b=5.16, zeta=0.01 in 21.06 seconds.
# Started solving for A=0.0, k_b=5.16, zeta=0.002...
# Completed for A=0.0, k_b=5.16, zeta=0.002 in 52.94 seconds.

# %%
import matplotlib.pyplot as plt

alpha = 0.001
beta = 1
A = 0.0

processed_kbs = set()
for A, kb, zeta in A_kb_zeta_list:
    if kb in processed_kbs:
        continue
    processed_kbs.add(kb)

for current_k_b in processed_kbs:
    figure = plt.figure(figsize=(16,12))
    for A, k_b, zeta in A_kb_zeta_list:
        if k_b == current_k_b:
            df = pd.read_csv(f'data/comparison/sticky_model/Gp_Gpp_output_A_{A}_k_b_{k_b}_zeta_{zeta}_alpha_{alpha}_beta_{beta}.csv')
            plt.loglog(df['omega'], df['G_p'], label=f"G' (A={A}, k_b={k_b}, zeta={zeta})")
            plt.loglog(df['omega'], df['G_pp'], linestyle='--', label=f"G'' (A={A}, k_b={k_b}, zeta={zeta})")
    # plt.loglog(paper_sticky_model_G_p_alpha_1["omega"], paper_sticky_model_G_p_alpha_1["G'"], color='r', label="G'' (paper data)")
    # plt.loglog(paper_sticky_model_G_pp_alpha_1["omega"], paper_sticky_model_G_pp_alpha_1["G''"], color='r', linestyle='--', label="G'' (paper data)") 
    plt.title(r"Dynamic shear moduli for sticky model with $\alpha = 0.001, \beta = 1, M=5, N_b=31$")
    plt.xlabel(r"$\omega$")
    plt.ylabel(r"$G', G''$")
    plt.xlim(1e-2, 1e4)
    plt.ylim(1e-3, 1e1)
    plt.tick_params(axis='both', which='both', direction='in', top=True, right=True)
    plt.legend()
    plt.grid()  
    plt.show()
